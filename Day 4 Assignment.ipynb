# %%
ReqAlt= int(input("Enter the Altitude of the plane Now - "))
if ReqAlt < 1000:
  print("Safe to land ! , Please Land the plane")
elif ReqAlt < 1000 & ReqAlt > 5000:
  print("Please come down to 1000ft !")
else:
  print("Turn around and try later ! ")
# Out:
# Enter the Altitude of the plane Now - 990
# Safe to land ! , Please Land the plane
